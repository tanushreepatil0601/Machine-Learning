# %% [markdown]
# # Data science

# %%
It is a process of extracting knowledge and insights from data by using scientific methods.
Extracting meaningful information from raw data.

# %% [markdown]
# ## Scientific methods

# %%
scientific methods are used to extract information from the data

# %%
1. Machine learning - used when data is in csv,excel etc.
2. Natural language processing - used when data is text data
3. Deep learning - used when data is images,videos,audio etc.
4. Statistics - mean,median,mode,hypothesis testing 
5. Data visualization - seaborn,matplotlib

# %%
ML and DL algorithms are predictive algorithms (it can be 99% correct)

# %% [markdown]
# # Data

# %% [raw]
# Data is a set of facts such as descriptions, observations, and numbers used in decision making.

# %% [markdown]
# ## Types of data

# %% [markdown]
# ## 1. Structured data

# %% [markdown]
# Structured data is generally tabular data that is represented by columns and rows in a database.
# eg. csv,excel etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.Semi-structured data

# %% [raw]
# 1. Semi-structured data is information that doesn’t consist of Structured data (relational database) but still has
#    some structure to it.
#
# 2. Semi-structured data consist of documents held in JavaScript Object Notation (JSON) format.
#    It also includes key-value stores and graph databases.
#    eg. json,html etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.unstructured data

# %% [raw]
# 1. Unstructured data is information that either does not organize in a pre-defined manner
#    or not have a pre-defined data model.
#
# 2. Unstructured information is a set of text-heavy but may contain data such as numbers, dates,
#    and facts as well.
#
# 3. Videos, audio, and binary data files might not have a specific structure. They’re assigned
#    to as unstructured data.
#    eg. text,images,videos,audio,PDF etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Application of Data science

# %% [raw]
# 1. Recommendation systems(Amazon,Flipkart)
# 2. Stock price prediction
# 3. Medical field (Cancer,diabetes,covid)
# 4. Finance domain(bank,NBFC)
# 5. Insurance domain(Mediassist) - Invoice
# 6. Handwritten character recognition
# 7. Self driven cars(Driverless cars) - object detection algorithms are used here
# 8. House price prediction
# 9. Speech recognition
# 10.Face recognition (video kyc done by bank for account opening)
# 11.Chatbots
# 12.Weather forecasting
# 13.Google maps

# %% [markdown]
# # Machine learning

# %% [raw]
# It is a subset of data science(AI)
#
# Training data > 75%  > Model will learn from this data(seen data)
# Testing data  > 25%  > Model will be tested on this data(unseen data)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Types of variables

# %% [raw]
# 1. Independant/Input variables/predictor - It is input to ML model
#                                          - It can be single or multiple
#
# 2. Dependant/ Output / Target variable - It is output of ML model.
#                                        - It is single only.

# %% [markdown]
# # Types of Machine learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1. Supervised machine learning - Training using labelled data
#                                - It is having both independant variables and target /dependentvariables.
#                                - It is trained under some supervision.
#
# 2. Unsupervised machine learning - Training using unlabelled data
#                                  - It is having only independant variables and no target/dependent variable.
#                                  - It is not trained under supervision.

# %% [markdown]
# # Types of supervised machine learning

# %% [markdown]
# ## 1.Regression

# %% [raw]
# Output variable is continous(Numerical values)
#
# eg. Stock price prediction,House price prediction etc.

# %% [markdown]
# ## 2.Classification

# %% [raw]
# Output variable is catergorical(Text,String)
#
# eg. True/False , Yes/No , Win/Loose , 1/0 etc.
#
# 1. Binary classification - only 2 unique values in target column
#                            True/False , Yes/No
#
# 2. Multiclass classification - more than 2 unique values in target column
#      a) Ordinal classification - Values are having inherit order.
#         eg Low/Medium/High
#            SSC,HSC,BE,ME,PHD
#
#
#      b) Multinomial classification - Values dont have inherit order.
#         eg Pune,Mumbai,Delhi,Kolkatta
#            Aadhar card,Pan card, Driving license

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Supervised machine learning algorithms

# %% [raw]
# 1. Linear regression(Regression problems)
# 2. Logistic regression(Classification problem (string,text))
# 3. K-nearest neighbour (Regression and Classification)
# 4. Decision tree (Regression and Classification)
# 5. Random forest (Regression and Classification)
# 6. Adaboost (Regression and Classification)
# 7. Gradient boost(Regression and Classification)
# 8. XGBoost (Regression and Classification)
# 10. Support vector machine(Regression and Classification)
# 9. Naive bayes algorithm(Classification)

# %% [markdown]
# # Unsupervised machine learning algorithms

# %% [raw]
# 1. K means clustering
# 2. hierarchical clustering
# 3. Principal component analysis
# 4. Apriori algorithm

# %% [markdown]
# # Data science project steps

# %% [raw]
# 1. Problem statement - define input and output variables
# 2. Data gathering (read the data)
# 3. Exploratory data analysis(EDA)
#     1. univariate,bivariate,multivariate analysis
#     2. Missing values handling
#     3. Datatype of columns(Encoding)
#     4. Outliers handling
#     5. Skewness
#     6. Scaling
# 4. Feature engineering
# 5. Feature selection
# 6. Model training
# 7. Model evaluation
# 8. Deployment (AWS,GCP)
